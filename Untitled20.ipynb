# %% [markdown]
# <a href="https://colab.research.google.com/github/sankari021/weather_app/blob/main/Untitled20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gTTS

# %%
from gtts import  gTTS
from IPython.display import Audio

# %%
a = gTTS(input("Enter any text:"))
# Out:
# Enter any text:hi hello good morning

# %%
a

# %%
a.save("speech.mp3")

# %%
Audio("speech.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !pip install SpeechRecognition pydub

# %%
from pydub import  AudioSegment

mp3_file = "/content/21db-366d-47c5-811b-e5288f2e37d6.mp3"
wav_file = "/content/speech.wav"

audio = AudioSegment.from_mp3(mp3_file)
audio.export(wav_file, format="wav")
# Out:
# <_io.BufferedRandom name='/content/speech.wav'>

# %%
import speech_recognition as sr
reco = sr.Recognizer()
import speech_recognition as sr
reco = sr.Recognizer()
with sr.AudioFile("/content/speech.wav") as source:
  audio_data = reco.record(source)
  print("Transcript: ", reco.recognize_google(audio_data))
# Out:
# Transcript:  in this light the basket is designed to scan a specified directory for empty files and temporary temporary files function function to safety delete a file this function is used to safely delete a file after logging it this locks the file that is about to be deleted along with the current data and time to log file this log entry records the data and time of deletion along with the file names RM - I this is the actual delicious command for the file for the use of confirmation before deleting each 55 scanning the directory of 4563 Target directory for temporary and amplifier outputs a message indicating that the script is about to begin scanning the directory Define by the Target directory variable find Target directions for file within the direct within the target directions

# %%
# !pip install pytesseract pillow

# %%
from PIL import Image
import pytesseract
import matplotlib.pyplot as plt
ip = "/content/my-word-search-title-w1000-h1416-preview-0.png"
plt.imshow(Image.open(ip))
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(999.5), np.float64(1415.5), np.float64(-0.5))

# %%
img = Image.open(ip)
text = pytesseract.image_to_string(img)
print("Extracted text:",text)
# Out:
# Extracted text:
#
# T hape you find what you're laching for oul there.
#
# T hape you find the hind of happiness that. exists
# on your sun terms. I hape you truly take the time
# te figure out: what moves you, what encourages your
# seul what you deeply crave from life, and I hape
#
# yow have the courage te chase that. I hepe yaw have
# the courage te believe that yaw are desewing of
# worthy of curating the hind of life for yourself that
# sparks, something within you. You have a fire
# inside of you I hape you never let canvenience, or
# comfort, or the easiness of stand- ing still put ¢
# out. I hepe you show the world what yew can de
#
# e =
#
# \WAVORKSHEET.Z0Nc__Scan-Here-ForDigitalVersion- meee

# %%
from gtts import  gTTS
from IPython.display import Audio

# %%
a = gTTS(input("Extracted text:"))
# Out:
# Extracted text:hi hello

# %%
a

# %%
a.save("speech.mp3")

# %%
Audio("speech.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !pip install googletrans==4.0.0-rc1

# %%
from googletrans import Translator
t = Translator()
text = input("Enter any text:")
transalated = t.translate(text, dest=' ')
# Use an f-string to correctly format the output string
print(f"transalated.text: {transalated.text}")
# Out:
# Enter any text:welcome
# transalated.text: स्वागत
